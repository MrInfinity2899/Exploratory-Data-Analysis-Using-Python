# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\user\anaconda3\imp\lib\site-packages (4.33.0)
# Requirement already satisfied: urllib3~=2.4.0 in c:\users\user\anaconda3\imp\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (2025.6.15)
# Requirement already satisfied: typing_extensions~=4.13.2 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\user\anaconda3\imp\lib\site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\anaconda3\imp\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\imp\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\user\anaconda3\imp\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
# IMDb URL for movies released in 2024
url = "https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31"
url="https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=action"
# Open the URL
driver.get(url)

# Allow the page to load (you can adjust the sleep time if necessary)
time.sleep(3)

# Initialize lists to store the scraped data
titles = []
ratings = []
votings = []
durations = []
# Loop through all movie items on the page
#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
# //*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
movie_items = driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')#'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for movie_item in movie_items:#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/span/div/span/span[2]
    try:
        # Extract the movie title
        title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text

        # Extract the movie rating
        rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text

        # Extract the number of votes
        voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text

        # Extract the movie duration//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/div[2]/span[2]
        duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text

        # Append the data to the lists
        titles.append(title)
        ratings.append(rating)
        votings.append(voting)
        durations.append(duration)
    
    except Exception as e:
        # If any element is not found, skip this movie and print an error message
        print(f"Error extracting data for a movie: {e}")
        continue

# %%
# Create a DataFrame using the extracted data
df_action = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations,
    "Genre": ["Action"] * len(titles)
})


# # Save the DataFrame to a CSV file (optional)
df_action.to_csv('imdb_movies_2024_action.csv', index=False)

# Close the browser

# %%
df_action
# Out:
#                                                 Title Rating    Votes  \
# 0                                     1. Gladiator II    6.5   (253K)
# 1                                   2. Dune: Part Two    8.5   (643K)
# 2                                         3. Twisters    6.5   (176K)
# 3                                4. Kraven the Hunter    5.5    (63K)
# 4            5. The Ministry of Ungentlemanly Warfare    6.8   (139K)
# 5                             6. Deadpool & Wolverine    7.5   (508K)
# 6                               7. The Unholy Trinity    6.1    (522)
# 7                                    8. The Beekeeper    6.3   (162K)
# 8                            9. Venom: The Last Dance    6.0   (130K)
# 9                                       10. Civil War    7.0   (244K)
# 10                           11. Sonic the Hedgehog 3    6.9    (65K)
# 11                        12. Furiosa: A Mad Max Saga    7.5   (292K)
# 12                                13. Fight or Flight    6.4    (14K)
# 13                                       14. Carry-On    6.5   (172K)
# 14                                   15. The Fall Guy    6.8   (227K)
# 15                                    16. Land of Bad    6.6    (53K)
# 16                      17. The Count of Monte-Cristo    7.6    (37K)
# 17                                    18. Rebel Ridge    6.8    (91K)
# 18                                     19. Road House    6.2   (171K)
# 19                                   20. Freaky Tales    6.2   (7.3K)
# 20                                   21. William Tell    5.7   (3.2K)
# 21                                     22. Madame Web    4.1   (104K)
# 22                                   23. Dirty Angels    4.4   (4.1K)
# 23                                     24. Absolution    5.2     (9K)
# 24                                    25. Borderlands    4.7    (51K)
# 25                                         26. Damsel    6.1   (111K)
# 26                               27. Transformers One    7.6    (54K)
# 27                                        28. Argylle    5.6    (94K)
# 28                          29. Bad Boys: Ride or Die    6.5   (103K)
# 29                                      30. The Union    5.4    (54K)
# 30              31. Kingdom of the Planet of the Apes    6.8   (155K)
# 31                               32. Drive-Away Dolls    5.4    (24K)
# 32                                       33. 40 Acres    6.8    (381)
# 33                                       34. Maharaja    8.4    (70K)
# 34                                       35. The Crow    4.7    (37K)
# 35                                     36. Monkey Man    6.8    (94K)
# 36                37. Godzilla x Kong: The New Empire    6.0   (124K)
# 37                                         38. Thelma    7.0    (24K)
# 38                                        39. Red One    6.3   (142K)
# 39                                        40. Survive    4.6   (3.2K)
# 40                                      41. Homestead    5.2   (4.2K)
# 41                                42. Kung Fu Panda 4    6.3    (70K)
# 42  43. The Lord of the Rings: The War of the Rohi...    6.3    (33K)
# 43                                 44. The Prosecutor    6.6   (2.7K)
# 44                                      45. Elevation    5.6    (24K)
# 45                                46. The Instigators    6.2    (39K)
# 46                                        47. Old Guy    5.2   (3.1K)
# 47                                     48. The Killer    5.7    (14K)
# 48                              49. The Killer's Game    5.8    (18K)
# 49                      50. Beverly Hills Cop: Axel F    6.4    (83K)
#
#    Duration   Genre
# 0    2h 28m  Action
# 1    2h 46m  Action
# 2     2h 2m  Action
# 3     2h 7m  Action
# 4     2h 2m  Action
# 5     2h 8m  Action
# 6    1h 35m  Action
# 7    1h 45m  Action
# 8    1h 50m  Action
# 9    1h 49m  Action
# 10   1h 50m  Action
# 11   2h 28m  Action
# 12   1h 42m  Action
# 13   1h 59m  Action
# 14    2h 6m  Action
# 15   1h 53m  Action
# 16   2h 58m  Action
# 17   2h 11m  Action
# 18    2h 1m  Action
# 19   1h 47m  Action
# 20   2h 14m  Action
# 21   1h 56m  Action
# 22   1h 44m  Action
# 23   1h 52m  Action
# 24   1h 41m  Action
# 25   1h 50m  Action
# 26   1h 44m  Action
# 27   2h 19m  Action
# 28   1h 55m  Action
# 29   1h 47m  Action
# 30   2h 25m  Action
# 31   1h 24m  Action
# 32   1h 53m  Action
# 33   2h 21m  Action
# 34   1h 51m  Action
# 35    2h 1m  Action
# 36   1h 55m  Action
# 37   1h 38m  Action
# 38    2h 3m  Action
# 39   1h 30m  Action
# 40   1h 52m  Action
# 41   1h 34m  Action
# 42   2h 14m  Action
# 43   1h 57m  Action
# 44   1h 31m  Action
# 45   1h 41m  Action
# 46   1h 34m  Action
# 47    2h 6m  Action
# 48   1h 44m  Action
# 49   1h 58m  Action

# %%
import selenium
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
# IMDb URL for movies released in 2024
url="https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=comedy"
# Open the URL
driver.get(url)

# Allow the page to load (you can adjust the sleep time if necessary)
time.sleep(3)

# Initialize lists to store the scraped data
titles = []
ratings = []
votings = []
durations = []
# Loop through all movie items on the page
#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
# //*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
movie_items = driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')#'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for movie_item in movie_items:#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/span/div/span/span[2]
    try:
        # Extract the movie title
        title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text

        # Extract the movie rating
        rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text

        # Extract the number of votes
        voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text

        # Extract the movie duration//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/div[2]/span[2]
        duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text

        # Append the data to the lists
        titles.append(title)
        ratings.append(rating)
        votings.append(voting)
        durations.append(duration)
    
    except Exception as e:
        # If any element is not found, skip this movie and print an error message
        print(f"Error extracting data for a movie: {e}")
        continue

# %%
df_comedy = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations,
    "Genre": ["Comedy"] * len(titles)
})


# # Save the DataFrame to a CSV file (optional)
df_comedy.to_csv('imdb_movies_2024_comedy.csv', index=False)

# %%
df_comedy
# Out:
#                                                 Title Rating    Votes  \
# 0                                     1. Gladiator II    6.5   (253K)
# 1                                   2. Dune: Part Two    8.5   (643K)
# 2                                         3. Twisters    6.5   (176K)
# 3                                4. Kraven the Hunter    5.5    (63K)
# 4            5. The Ministry of Ungentlemanly Warfare    6.8   (139K)
# 5                             6. Deadpool & Wolverine    7.5   (508K)
# 6                               7. The Unholy Trinity    6.1    (522)
# 7                                    8. The Beekeeper    6.3   (162K)
# 8                            9. Venom: The Last Dance    6.0   (130K)
# 9                                       10. Civil War    7.0   (244K)
# 10                           11. Sonic the Hedgehog 3    6.9    (65K)
# 11                        12. Furiosa: A Mad Max Saga    7.5   (292K)
# 12                                13. Fight or Flight    6.4    (14K)
# 13                                       14. Carry-On    6.5   (172K)
# 14                                   15. The Fall Guy    6.8   (227K)
# 15                                    16. Land of Bad    6.6    (53K)
# 16                      17. The Count of Monte-Cristo    7.6    (37K)
# 17                                    18. Rebel Ridge    6.8    (91K)
# 18                                     19. Road House    6.2   (171K)
# 19                                   20. Freaky Tales    6.2   (7.3K)
# 20                                   21. William Tell    5.7   (3.2K)
# 21                                     22. Madame Web    4.1   (104K)
# 22                                   23. Dirty Angels    4.4   (4.1K)
# 23                                     24. Absolution    5.2     (9K)
# 24                                    25. Borderlands    4.7    (51K)
# 25                                         26. Damsel    6.1   (111K)
# 26                               27. Transformers One    7.6    (54K)
# 27                                        28. Argylle    5.6    (94K)
# 28                          29. Bad Boys: Ride or Die    6.5   (103K)
# 29                                      30. The Union    5.4    (54K)
# 30              31. Kingdom of the Planet of the Apes    6.8   (155K)
# 31                               32. Drive-Away Dolls    5.4    (24K)
# 32                                       33. 40 Acres    6.8    (381)
# 33                                       34. Maharaja    8.4    (70K)
# 34                                       35. The Crow    4.7    (37K)
# 35                                     36. Monkey Man    6.8    (94K)
# 36                37. Godzilla x Kong: The New Empire    6.0   (124K)
# 37                                         38. Thelma    7.0    (24K)
# 38                                        39. Red One    6.3   (142K)
# 39                                        40. Survive    4.6   (3.2K)
# 40                                      41. Homestead    5.2   (4.2K)
# 41                                42. Kung Fu Panda 4    6.3    (70K)
# 42  43. The Lord of the Rings: The War of the Rohi...    6.3    (33K)
# 43                                 44. The Prosecutor    6.6   (2.7K)
# 44                                      45. Elevation    5.6    (24K)
# 45                                46. The Instigators    6.2    (39K)
# 46                                        47. Old Guy    5.2   (3.1K)
# 47                                     48. The Killer    5.7    (14K)
# 48                              49. The Killer's Game    5.8    (18K)
# 49                      50. Beverly Hills Cop: Axel F    6.4    (83K)
#
#    Duration   Genre
# 0    2h 28m  Comedy
# 1    2h 46m  Comedy
# 2     2h 2m  Comedy
# 3     2h 7m  Comedy
# 4     2h 2m  Comedy
# 5     2h 8m  Comedy
# 6    1h 35m  Comedy
# 7    1h 45m  Comedy
# 8    1h 50m  Comedy
# 9    1h 49m  Comedy
# 10   1h 50m  Comedy
# 11   2h 28m  Comedy
# 12   1h 42m  Comedy
# 13   1h 59m  Comedy
# 14    2h 6m  Comedy
# 15   1h 53m  Comedy
# 16   2h 58m  Comedy
# 17   2h 11m  Comedy
# 18    2h 1m  Comedy
# 19   1h 47m  Comedy
# 20   2h 14m  Comedy
# 21   1h 56m  Comedy
# 22   1h 44m  Comedy
# 23   1h 52m  Comedy
# 24   1h 41m  Comedy
# 25   1h 50m  Comedy
# 26   1h 44m  Comedy
# 27   2h 19m  Comedy
# 28   1h 55m  Comedy
# 29   1h 47m  Comedy
# 30   2h 25m  Comedy
# 31   1h 24m  Comedy
# 32   1h 53m  Comedy
# 33   2h 21m  Comedy
# 34   1h 51m  Comedy
# 35    2h 1m  Comedy
# 36   1h 55m  Comedy
# 37   1h 38m  Comedy
# 38    2h 3m  Comedy
# 39   1h 30m  Comedy
# 40   1h 52m  Comedy
# 41   1h 34m  Comedy
# 42   2h 14m  Comedy
# 43   1h 57m  Comedy
# 44   1h 31m  Comedy
# 45   1h 41m  Comedy
# 46   1h 34m  Comedy
# 47    2h 6m  Comedy
# 48   1h 44m  Comedy
# 49   1h 58m  Comedy

# %%
import selenium
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
# IMDb URL for movies released in 2024
url="https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=horror"
# Open the URL
driver.get(url)

# Allow the page to load (you can adjust the sleep time if necessary)
time.sleep(3)

# Initialize lists to store the scraped data
titles = []
ratings = []
votings = []
durations = []
# Loop through all movie items on the page
#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
# //*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
movie_items = driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')#'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for movie_item in movie_items:#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/span/div/span/span[2]
    try:
        # Extract the movie title
        title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text

        # Extract the movie rating
        rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text

        # Extract the number of votes
        voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text

        # Extract the movie duration//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/div[2]/span[2]
        duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text

        # Append the data to the lists
        titles.append(title)
        ratings.append(rating)
        votings.append(voting)
        durations.append(duration)
    
    except Exception as e:
        # If any element is not found, skip this movie and print an error message
        print(f"Error extracting data for a movie: {e}")
        continue

# %%
df_horror = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations,
    "Genre": ["Horror"] * len(titles)
})


# # Save the DataFrame to a CSV file (optional)
df_horror.to_csv('imdb_movies_2024_horror.csv', index=False)

# %%
df_horror
# Out:
#                                          Title Rating    Votes Duration  \
# 0                                   1. Heretic    7.0   (162K)   1h 51m
# 1                             2. The Substance    7.2   (319K)   2h 21m
# 2                                 3. Nosferatu    7.2   (210K)   2h 12m
# 3                                  4. Presence    6.1    (29K)   1h 24m
# 4                             5. Speak No Evil    6.8   (110K)   1h 50m
# 5                            6. Alien: Romulus    7.1   (254K)   1h 59m
# 6                                  7. Longlegs    6.6   (193K)   1h 41m
# 7                   8. Beetlejuice Beetlejuice    6.6   (155K)   1h 45m
# 8                               9. The Shrouds    5.8   (3.7K)       2h
# 9                                     10. Trap    5.8   (145K)   1h 45m
# 10                                 11. Smile 2    6.7   (114K)    2h 7m
# 11                             12. Terrifier 3    6.3    (52K)    2h 5m
# 12                                 13. Abigail    6.5   (100K)   1h 49m
# 13                                14. MaXXXine    6.2    (74K)   1h 43m
# 14                                    15. 1978    5.2    (484)   1h 16m
# 15                                  16. Oddity    6.7    (46K)   1h 38m
# 16                       17. Kinds of Kindness    6.5    (61K)   2h 44m
# 17                  18. A Quiet Place: Day One    6.3   (155K)   1h 39m
# 18                             19. Salem's Lot    5.6    (35K)   1h 54m
# 19                     20. Out Come the Wolves    4.7   (1.7K)   1h 26m
# 20                              21. Don't Move    5.8    (41K)   1h 32m
# 21                                  22. Cuckoo    5.7    (29K)   1h 42m
# 22                                23. The Crow    4.7    (37K)   1h 51m
# 23                                24. Time Cut    5.0    (20K)   1h 31m
# 24                                     25. Y2K    4.8    (16K)   1h 31m
# 25                                 26. Survive    4.6   (3.2K)   1h 30m
# 26                              27. Immaculate    5.8    (54K)   1h 29m
# 27                            28. The Watchers    5.7    (59K)   1h 42m
# 28                              29. The Damned    5.7   (5.6K)   1h 29m
# 29          30. Please Don't Feed the Children    6.2     (91)   1h 34m
# 30                                31. Outbreak    4.4   (1.2K)   1h 28m
# 31                   32. The Rule of Jenny Pen    6.2     (6K)   1h 44m
# 32                                33. The Twin    8.1     (63)   1h 43m
# 33                                34. Bleeding    4.4    (339)   1h 37m
# 34                          35. The First Omen    6.5    (66K)   1h 59m
# 35                             36. The Wailing    6.1   (1.6K)   1h 47m
# 36                                    37. MadS    6.4   (8.8K)   1h 29m
# 37                              38. Nightbitch    5.5    (21K)   1h 39m
# 38                              39. Witchboard    7.6    (106)   1h 52m
# 39                         40. The Deliverance    5.1    (23K)   1h 52m
# 40                                41. Arcadian    5.5    (24K)   1h 32m
# 41  42. Apocalypse Z: The Beginning of the End    6.1    (21K)   1h 57m
# 42                             43. Saint Clare    7.3    (109)   1h 32m
# 43                                   44. Chime    6.4   (2.7K)      45m
# 44                            45. Apartment 7A    5.9    (17K)   1h 47m
# 45                                  46. Exhuma    6.9    (25K)   2h 14m
# 46                                   47. Tarot    4.8    (33K)   1h 32m
# 47                     48. In a Violent Nature    5.6    (28K)   1h 34m
# 48                                  49. Azrael    5.4    (12K)   1h 26m
# 49                            50. Never Let Go    5.4    (16K)   1h 41m
#
#      Genre
# 0   Horror
# 1   Horror
# 2   Horror
# 3   Horror
# 4   Horror
# 5   Horror
# 6   Horror
# 7   Horror
# 8   Horror
# 9   Horror
# 10  Horror
# 11  Horror
# 12  Horror
# 13  Horror
# 14  Horror
# 15  Horror
# 16  Horror
# 17  Horror
# 18  Horror
# 19  Horror
# 20  Horror
# 21  Horror
# 22  Horror
# 23  Horror
# 24  Horror
# 25  Horror
# 26  Horror
# 27  Horror
# 28  Horror
# 29  Horror
# 30  Horror
# 31  Horror
# 32  Horror
# 33  Horror
# 34  Horror
# 35  Horror
# 36  Horror
# 37  Horror
# 38  Horror
# 39  Horror
# 40  Horror
# 41  Horror
# 42  Horror
# 43  Horror
# 44  Horror
# 45  Horror
# 46  Horror
# 47  Horror
# 48  Horror
# 49  Horror

# %%
import selenium
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
# IMDb URL for movies released in 2024
url="https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=adventure"
# Open the URL
driver.get(url)

# Allow the page to load (you can adjust the sleep time if necessary)
time.sleep(3)

# Initialize lists to store the scraped data
titles = []
ratings = []
votings = []
durations = []
# Loop through all movie items on the page
#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
# //*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
movie_items = driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')#'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for movie_item in movie_items:#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/span/div/span/span[2]
    try:
        # Extract the movie title
        title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text

        # Extract the movie rating
        rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text

        # Extract the number of votes
        voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text

        # Extract the movie duration//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/div[2]/span[2]
        duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text

        # Append the data to the lists
        titles.append(title)
        ratings.append(rating)
        votings.append(voting)
        durations.append(duration)
    
    except Exception as e:
        # If any element is not found, skip this movie and print an error message
        print(f"Error extracting data for a movie: {e}")
        continue

# %%
df_adventure = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations,
    "Genre": ["Adventure"] * len(titles)
})


# # Save the DataFrame to a CSV file (optional)
df_adventure.to_csv('imdb_movies_2024_adventure.csv', index=False)

# %%
df_adventure
# Out:
#                                                 Title Rating    Votes  \
# 0                                     1. Gladiator II    6.5   (253K)
# 1                                   2. Dune: Part Two    8.5   (643K)
# 2                                         3. Twisters    6.5   (176K)
# 3                                4. Kraven the Hunter    5.5    (63K)
# 4                             5. Deadpool & Wolverine    7.5   (508K)
# 5                               6. The Unholy Trinity    6.1    (522)
# 6                            7. Venom: The Last Dance    6.0   (130K)
# 7                             8. Sonic the Hedgehog 3    6.9    (65K)
# 8                                             9. Flow    7.9    (84K)
# 9                         10. Furiosa: A Mad Max Saga    7.5   (292K)
# 10                                        11. Moana 2    6.5   (109K)
# 11                          12. Mufasa: The Lion King    6.6    (71K)
# 12                      13. The Count of Monte-Cristo    7.6    (37K)
# 13                                   14. Freaky Tales    6.2   (7.3K)
# 14                             15. Paddington in Peru    6.7    (26K)
# 15                                   16. Inside Out 2    7.5   (223K)
# 16                    17. Ghostbusters: Frozen Empire    6.1    (96K)
# 17                                     18. The Return    6.2    (10K)
# 18                                    19. Borderlands    4.7    (51K)
# 19                                         20. Damsel    6.1   (111K)
# 20                               21. Transformers One    7.6    (54K)
# 21                                22. Despicable Me 4    6.2    (68K)
# 22                          23. Bad Boys: Ride or Die    6.5   (103K)
# 23              24. Kingdom of the Planet of the Apes    6.8   (155K)
# 24                                 25. Monster Summer    5.7   (4.2K)
# 25                26. Godzilla x Kong: The New Empire    6.0   (124K)
# 26                                        27. Red One    6.3   (142K)
# 27                                        28. Survive    4.6   (3.2K)
# 28  29. The Day the Earth Blew Up: A Looney Tunes ...    6.9   (5.5K)
# 29                                30. Kung Fu Panda 4    6.3    (70K)
# 30  31. The Lord of the Rings: The War of the Rohi...    6.3    (33K)
# 31                                         32. Uglies    4.7    (34K)
# 32                             33. The Garfield Movie    5.7    (25K)
# 33     34. Attack on Titan the Movie: The Last Attack    9.2    (18K)
# 34                                       35. Spaceman    5.7    (44K)
# 35                                  36. Kalki 2898 AD    7.0    (68K)
# 36                                 37. Cells at Work!    6.7    (849)
# 37                     38. Solo Leveling: ReAwakening    8.8    (14K)
# 38                                39. Arthur the King    7.0    (35K)
# 39                                          40. Atlas    5.6    (57K)
# 40                                     41. Spellbound    5.5   (7.9K)
# 41                                         42. Sketch    8.2     (71)
# 42          43. Wallace & Gromit: Vengeance Most Fowl    7.5    (36K)
# 43                    44. Lost on a Mountain in Maine    6.1   (1.6K)
# 44           45. Rebel Moon - Part Two: The Scargiver    5.3    (60K)
# 45                                 46. Manjummel Boys    8.2    (28K)
# 46                   47. Descendants: The Rise of Red    4.7   (7.3K)
# 47                   48. Harold and the Purple Crayon    5.7   (8.8K)
# 48                                  49. Devara Part 1    6.0    (21K)
# 49                                    50. Family Pack    5.5   (9.6K)
#
#    Duration      Genre
# 0    2h 28m  Adventure
# 1    2h 46m  Adventure
# 2     2h 2m  Adventure
# 3     2h 7m  Adventure
# 4     2h 8m  Adventure
# 5    1h 35m  Adventure
# 6    1h 50m  Adventure
# 7    1h 50m  Adventure
# 8    1h 25m  Adventure
# 9    2h 28m  Adventure
# 10   1h 40m  Adventure
# 11   1h 58m  Adventure
# 12   2h 58m  Adventure
# 13   1h 47m  Adventure
# 14   1h 46m  Adventure
# 15   1h 36m  Adventure
# 16   1h 55m  Adventure
# 17   1h 56m  Adventure
# 18   1h 41m  Adventure
# 19   1h 50m  Adventure
# 20   1h 44m  Adventure
# 21   1h 34m  Adventure
# 22   1h 55m  Adventure
# 23   2h 25m  Adventure
# 24   1h 37m  Adventure
# 25   1h 55m  Adventure
# 26    2h 3m  Adventure
# 27   1h 30m  Adventure
# 28   1h 31m  Adventure
# 29   1h 34m  Adventure
# 30   2h 14m  Adventure
# 31   1h 40m  Adventure
# 32   1h 41m  Adventure
# 33   2h 25m  Adventure
# 34   1h 47m  Adventure
# 35       3h  Adventure
# 36   1h 49m  Adventure
# 37    2h 1m  Adventure
# 38   1h 47m  Adventure
# 39   1h 58m  Adventure
# 40   1h 49m  Adventure
# 41   1h 32m  Adventure
# 42   1h 22m  Adventure
# 43   1h 38m  Adventure
# 44    2h 2m  Adventure
# 45   2h 15m  Adventure
# 46   1h 31m  Adventure
# 47   1h 30m  Adventure
# 48   2h 56m  Adventure
# 49   1h 34m  Adventure

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\user\anaconda3\imp\lib\site-packages (4.33.0)
# Requirement already satisfied: urllib3~=2.4.0 in c:\users\user\anaconda3\imp\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (2025.6.15)
# Requirement already satisfied: typing_extensions~=4.13.2 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\user\anaconda3\imp\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\imp\lib\site-packages (from trio~=0.30.0->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\user\anaconda3\imp\lib\site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\anaconda3\imp\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\imp\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\user\anaconda3\imp\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
# IMDb URL for movies released in 2024
url="https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=fantasy"
# Open the URL
driver.get(url)

# Allow the page to load (you can adjust the sleep time if necessary)
time.sleep(3)

# Initialize lists to store the scraped data
titles = []
ratings = []
votings = []
durations = []
genre =[]

# Loop through all movie items on the page
#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
# //*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul
movie_items = driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')#'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for movie_item in movie_items:#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/span/div/span/span[2]
    try:
        # Extract the movie title
        title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text

        # Extract the movie rating
        rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text

        # Extract the number of votes
        voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text

        # Extract the movie duration//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[1]/div/div/div/div[1]/div[2]/div[2]/span[2]
        duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text
        
        # Extract the genre name
        #genre_elements = driver.find_elements(By.XPATH,"//span[@class = 'ipc-chip__text']")
        #genre = [a.text for a in genre_elements]
        #for genre in genre:
            #print(genre)

        

        # Append the data to the lists
        titles.append(title)
        ratings.append(rating)
        votings.append(voting)
        durations.append(duration)
        
    
    except Exception as e:
        # If any element is not found, skip this movie and print an error message
        print(f"Error extracting data for a movie: {e}")
        continue

# %%
df_fantasy = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations,
    "Genre": ["Fantasy"] * len(titles)
    
    
})


# # Save the DataFrame to a CSV file (optional)
df_fantasy.to_csv('imdb_movies_2024_fantasy.csv', index=False)

# %%
df_fantasy
# Out:
#                                                 Title Rating    Votes  \
# 0                                1. The Life of Chuck    7.7   (6.7K)
# 1                                        2. Nosferatu    7.2   (210K)
# 2                                           3. Wicked    7.4   (169K)
# 3                             4. Sonic the Hedgehog 3    6.9    (65K)
# 4                                             5. Flow    7.9    (84K)
# 5                                       6. Parthenope    6.6    (14K)
# 6                          7. Beetlejuice Beetlejuice    6.6   (155K)
# 7                                          8. Moana 2    6.5   (109K)
# 8                                       9. Better Man    7.6    (32K)
# 9                                    10. Inside Out 2    7.5   (223K)
# 10                    11. Ghostbusters: Frozen Empire    6.1    (96K)
# 11                                         12. Damsel    6.1   (111K)
# 12                                    13. Megalopolis    4.7    (37K)
# 13                               14. Transformers One    7.6    (54K)
# 14                                             15. IF    6.4    (60K)
# 15                                 16. Monster Summer    5.7   (4.2K)
# 16                                       17. The Crow    4.7    (37K)
# 17                18. Godzilla x Kong: The New Empire    6.0   (124K)
# 18                                        19. Red One    6.3   (142K)
# 19                                   20. The Watchers    5.7    (59K)
# 20                                21. Kung Fu Panda 4    6.3    (70K)
# 21  22. The Lord of the Rings: The War of the Rohi...    6.3    (33K)
# 22  23. The Wonderful Story of Henry Sugar and Thr...    7.1   (8.2K)
# 23                                         24. Uglies    4.7    (34K)
# 24                             25. The Garfield Movie    5.7    (25K)
# 25                                  26. Kalki 2898 AD    7.0    (68K)
# 26                                 27. Cells at Work!    6.7    (849)
# 27                     28. Solo Leveling: ReAwakening    8.8    (14K)
# 28                                     29. Spellbound    5.5   (7.9K)
# 29                       30. The Master and Margarita    7.2     (5K)
# 30                                         31. Sketch    8.2     (71)
# 31           32. Rebel Moon - Part Two: The Scargiver    5.3    (60K)
# 32                                        33. The End    5.5   (2.3K)
# 33                   34. Descendants: The Rise of Red    4.7   (7.3K)
# 34                   35. Harold and the Purple Crayon    5.7   (8.8K)
# 35                                     36. Dear Santa    5.4    (19K)
# 36                                    37. Family Pack    5.5   (9.6K)
# 37                                  38. The Tearsmith    5.2    (13K)
# 38                             39. Orion and the Dark    6.3    (18K)
# 39                                40. Girl Haunts Boy    6.3   (3.4K)
# 40                                   41. Dragonkeeper    5.7   (1.8K)
# 41  42. Justice League: Crisis on Infinite Earths ...    6.2   (8.8K)
# 42  43. Justice League: Crisis on Infinite Earths ...    6.1   (4.8K)
# 43                                     44. Irish Wish    5.2    (22K)
# 44                    45. Dan Da Dan: First Encounter    8.2     (3K)
# 45                              46. Bhool Bhulaiyaa 3    4.6    (78K)
# 46                             47. Thelma the Unicorn    5.7     (3K)
# 47                      48. Night of the Zoopocalypse    6.1    (928)
# 48  49. Justice League: Crisis on Infinite Earths ...    5.5   (5.6K)
# 49                                50. The Balconettes    5.8   (1.4K)
#
#    Duration    Genre
# 0    1h 51m  Fantasy
# 1    2h 12m  Fantasy
# 2    2h 40m  Fantasy
# 3    1h 50m  Fantasy
# 4    1h 25m  Fantasy
# 5    2h 17m  Fantasy
# 6    1h 45m  Fantasy
# 7    1h 40m  Fantasy
# 8    2h 15m  Fantasy
# 9    1h 36m  Fantasy
# 10   1h 55m  Fantasy
# 11   1h 50m  Fantasy
# 12   2h 18m  Fantasy
# 13   1h 44m  Fantasy
# 14   1h 44m  Fantasy
# 15   1h 37m  Fantasy
# 16   1h 51m  Fantasy
# 17   1h 55m  Fantasy
# 18    2h 3m  Fantasy
# 19   1h 42m  Fantasy
# 20   1h 34m  Fantasy
# 21   2h 14m  Fantasy
# 22   1h 28m  Fantasy
# 23   1h 40m  Fantasy
# 24   1h 41m  Fantasy
# 25       3h  Fantasy
# 26   1h 49m  Fantasy
# 27    2h 1m  Fantasy
# 28   1h 49m  Fantasy
# 29   2h 36m  Fantasy
# 30   1h 32m  Fantasy
# 31    2h 2m  Fantasy
# 32   2h 28m  Fantasy
# 33   1h 31m  Fantasy
# 34   1h 30m  Fantasy
# 35   1h 47m  Fantasy
# 36   1h 34m  Fantasy
# 37   1h 43m  Fantasy
# 38   1h 33m  Fantasy
# 39   1h 40m  Fantasy
# 40   1h 38m  Fantasy
# 41   1h 33m  Fantasy
# 42   1h 34m  Fantasy
# 43   1h 33m  Fantasy
# 44   1h 23m  Fantasy
# 45   2h 38m  Fantasy
# 46   1h 33m  Fantasy
# 47   1h 31m  Fantasy
# 48   1h 34m  Fantasy
# 49   1h 44m  Fantasy

# %%
IMDB_list = pd.concat([df_action, df_adventure, df_horror, df_fantasy , df_comedy])

# %%
IMDB_list.to_csv('imdb_movies_2024_list.csv', index=False)

# %%
IMDB_list
# Out:
#                                        Title Rating    Votes Duration   Genre
# 0                            1. Gladiator II    6.5   (253K)   2h 28m  Action
# 1                          2. Dune: Part Two    8.5   (643K)   2h 46m  Action
# 2                                3. Twisters    6.5   (176K)    2h 2m  Action
# 3                       4. Kraven the Hunter    5.5    (63K)    2h 7m  Action
# 4   5. The Ministry of Ungentlemanly Warfare    6.8   (139K)    2h 2m  Action
# ..                                       ...    ...      ...      ...     ...
# 45                       46. The Instigators    6.2    (39K)   1h 41m  Comedy
# 46                               47. Old Guy    5.2   (3.1K)   1h 34m  Comedy
# 47                            48. The Killer    5.7    (14K)    2h 6m  Comedy
# 48                     49. The Killer's Game    5.8    (18K)   1h 44m  Comedy
# 49             50. Beverly Hills Cop: Axel F    6.4    (83K)   1h 58m  Comedy
#
# [250 rows x 5 columns]

# %%
pip install mysql-connector-python sqlalchemy pandas
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.3.0-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: sqlalchemy in c:\users\user\anaconda3\imp\lib\site-packages (2.0.30)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\imp\lib\site-packages (2.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\anaconda3\imp\lib\site-packages (from sqlalchemy) (4.13.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\imp\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\anaconda3\imp\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\imp\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\imp\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\imp\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\imp\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading mysql_connector_python-9.3.0-cp312-cp312-win_amd64.whl (16.4 MB)
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB 495.5 kB/s eta 0:00:33
#    ---------------------------------------- 0.1/16.4 MB 819.2 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/16.4 MB 654.9 kB/s eta 0:00:25
#     --------------------------------------- 0.2/16.4 MB 831.5 kB/s eta 0:00:20
#     --------------------------------------- 0.4/16.4 MB 1.3 MB/s eta 0:00:13
#    - -------------------------------------- 0.7/16.4 MB 2.0 MB/s eta 0:00:08
#    -- ------------------------------------- 0.9/16.4 MB 2.6 MB/s eta 0:00:06
#    --- ------------------------------------ 1.3/16.4 MB 3.0 MB/s eta 0:00:05
#    --- ------------------------------------ 1.3/16.4 MB 3.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/16.4 MB 3.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.8/16.4 MB 3.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.1/16.4 MB 3.5 MB/s eta 0:00:05
#    ------ --------------------------------- 2.5/16.4 MB 3.9 MB/s eta 0:00:04
#    ------ --------------------------------- 2.8/16.4 MB 4.1 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/16.4 MB 4.0 MB/s eta 0:00:04
#    -------- ------------------------------- 3.3/16.4 MB 4.3 MB/s eta 0:00:04
#    -------- ------------------------------- 3.4/16.4 MB 4.2 MB/s eta 0:00:04
#    --------- ------------------------------ 3.8/16.4 MB 4.3 MB/s eta 0:00:03
#    --------- ------------------------------ 4.1/16.4 MB 4.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.5/16.4 MB 4.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.8/16.4 MB 4.8 MB/s eta 0:00:03
#    ------------- -------------------------- 5.4/16.4 MB 5.1 MB/s eta 0:00:03
#    ------------- -------------------------- 5.5/16.4 MB 5.0 MB/s eta 0:00:03
#    ------------- -------------------------- 5.6/16.4 MB 4.9 MB/s eta 0:00:03
#    ------------- -------------------------- 5.6/16.4 MB 4.9 MB/s eta 0:00:03
#    -------------- ------------------------- 6.0/16.4 MB 4.8 MB/s eta 0:00:03
#    --------------- ------------------------ 6.3/16.4 MB 4.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.7/16.4 MB 5.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.3/16.4 MB 5.2 MB/s eta 0:00:02
#    ------------------ --------------------- 7.6/16.4 MB 5.3 MB/s eta 0:00:02
#    ------------------ --------------------- 7.8/16.4 MB 5.2 MB/s eta 0:00:02
#    ------------------- -------------------- 8.1/16.4 MB 5.3 MB/s eta 0:00:02
#    -------------------- ------------------- 8.3/16.4 MB 5.3 MB/s eta 0:00:02
#    -------------------- ------------------- 8.3/16.4 MB 5.3 MB/s eta 0:00:02
#    -------------------- ------------------- 8.3/16.4 MB 5.0 MB/s eta 0:00:02
#    --------------------- ------------------ 8.9/16.4 MB 5.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.0/16.4 MB 5.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.1/16.4 MB 5.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.2/16.4 MB 5.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/16.4 MB 5.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/16.4 MB 4.9 MB/s eta 0:00:02
#    ------------------------ --------------- 9.9/16.4 MB 5.0 MB/s eta 0:00:02
#    ------------------------ --------------- 10.1/16.4 MB 5.0 MB/s eta 0:00:02
#    ------------------------- -------------- 10.5/16.4 MB 5.6 MB/s eta 0:00:02
#    -------------------------- ------------- 10.9/16.4 MB 5.7 MB/s eta 0:00:01
#    --------------------------- ------------ 11.3/16.4 MB 5.7 MB/s eta 0:00:01
#    --------------------------- ------------ 11.4/16.4 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.9/16.4 MB 6.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.9/16.4 MB 6.0 MB/s eta 0:00:01
#    ------------------------------ --------- 12.4/16.4 MB 5.8 MB/s eta 0:00:01
#    ------------------------------- -------- 12.8/16.4 MB 5.8 MB/s eta 0:00:01
#    ------------------------------- -------- 13.1/16.4 MB 6.0 MB/s eta 0:00:01
#    -------------------------------- ------- 13.3/16.4 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 13.7/16.4 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.9/16.4 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.3/16.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.3/16.4 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 14.8/16.4 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------ --- 15.0/16.4 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 15.5/16.4 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 15.8/16.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  16.2/16.4 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  16.4/16.4 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 6.0 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
